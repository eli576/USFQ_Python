# %% [markdown]
# <a href="https://colab.research.google.com/github/eli576/USFQ_Python/blob/main/taller_cc_deber_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Escribir un programa que transforme un número entero desde cualquiera de las bases 2, 3, 4, 5, 6, 7, 10 o 16 hacia cualquier otra de esas mismas bases.
#El número entero puede ser positivo o negativo.

#Si el número ingresado no está en base 10, conviértalo primero a base 10
# y luego a la base de destino seleccionada.


#Cuando la conversión involucre la base 2 (hacia o desde las otras bases mencionadas), y se requiera representar enteros con signo, utilice complemento a dos. En ese caso, solicite al usuario el número de bits de la representación.
#Valide que el número de bits elegido haga posible la representación en complemento a dos.
#Si no es posible, indique el error y pida otro valor de el número de bits.

# %%
numero_original = str(input("Ingresa un numero: ")).upper()
base_original = int(input("En que base es el numero que ingresaste? (2, 3, 4, 5, 6, 7, 10 o 16): "))
base_nuevo = int(input("A que base quieres transformar el numero? (2, 3, 4, 5, 6, 7, 10 o 16): "))

if base_original != 10:

  numero_base_10 = 0
  potencia = 0
  #Iterate through the digits in reverse order
  for i in reversed(numero_original):
    digito = 0
    if '0' <= i <= '9':
      digito = int(i)
    else:
      digito = ord(i) - ord('A') + 10

    numero_base_10 = numero_base_10 + (digito * (base_original ** potencia))
    potencia = potencia + 1

  print(f"The decimal value of {numero_original} in base {base_original} is: {numero_base_10}")


if base_original == 2:
  bits = int(input("Que numero de bits tiene la numero ingresada?: "))

if base_nuevo == 2:
  bits = int(input("En que numero de bits quieres tener la numero representada?: "))
  #evaluate if it works, #otherwise ask for other value - while loop


#convert numero_original in base_original to numero_nuevo in base_nuevo

# %%
numero_original_str = str(input("Ingresa un numero: ")).upper()
base_original = int(input("En que base es el numero que ingresaste? (2, 3, 4, 5, 6, 7, 10 o 16): "))
#base_nuevo = int(input("A que base quieres transformar el numero? (2, 3, 4, 5, 6, 7, 10 o 16): "))



if base_original != 10:

  if base_original == 16:
    for i in numero_original_str:
      if '0' <= i <= '9':
        numero_original = int(i)
      elif 'A' <= i <= 'F':
        numero_original = ord(i) - ord('A') + 10
      else:
        print(f"Error: Invalid digit '{digit}' for base {base_original}")
  else:
    numero_original = int(numero_original)

  print(numero_original)


  decimal_value = 0
  power = 0
  #Iterate through the digits in reverse order
  for i in reversed(numero_original):
    decimal_value += numero_original * (base ** power)
    power += 1
    print(decimal_value)
# Out:
# Ingresa un numero: 16d
# En que base es el numero que ingresaste? (2, 3, 4, 5, 6, 7, 10 o 16): 16
# 13
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2529162586.py in <cell line: 0>()
#      24   power = 0
#      25   #Iterate through the digits in reverse order
# ---> 26   for i in reversed(numero_original):
#      27     decimal_value += numero_original * (base ** power)
#      28     power += 1
#
# TypeError: 'int' object is not reversible

# %%
def digit_to_decimal(digit):
  """Converts a digit (as a string) from any base to its decimal value."""
  if '0' <= digit <= '9':
    return int(digit)
  elif 'A' <= digit <= 'F':
    return ord(digit) - ord('A') + 10
  else:
    raise ValueError("Invalid digit: {}".format(digit))

numero_original_str = str(input("Ingresa un numero: ")).upper()
base_original = int(input("En que base es el numero que ingresaste? (2, 3, 4, 5, 6, 7, 10 o 16): "))
base_nuevo = int(input("A que base quieres transformar el numero? (2, 3, 4, 5, 6, 7, 10 o 16): "))

decimal_value = 0
if base_original != 10:
  power = 0
  # Iterate through the digits in reverse order
  for digit in reversed(numero_original_str):
    decimal_value += digit_to_decimal(digit) * (base_original ** power)
    power += 1
else:
  # Assuming if base_original is 10, the input is a valid decimal number
  decimal_value = int(numero_original_str)

print(f"The decimal value of {numero_original_str} in base {base_original} is: {decimal_value}")


if base_original == 2:
  bits = int(input("Que numero de bits tiene la numero ingresada?: "))

if base_nuevo == 2:
  bits = int(input("En que numero de bits quieres tener la numero representada?: "))
  #evaluate if it works, #otherwise ask for other value - while loop


#convert numero_original in base_original to numero_nuevo in base_nuevo
# Out:
# Ingresa un numero: 17d
# En que base es el numero que ingresaste? (2, 3, 4, 5, 6, 7, 10 o 16): 16
# A que base quieres transformar el numero? (2, 3, 4, 5, 6, 7, 10 o 16): 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-214516160.py in <cell line: 0>()
#       8
#       9   if base_original == 16:
# ---> 10     ord(numero_original) - ord('A') + 10
#      11   else:
#      12     numero_original = int(numero_original)
#
# TypeError: ord() expected a character, but string of length 3 found

# %%
def base_to_decimal(number_str, base):
  """Converts a number represented as a string in a given base to its decimal value."""
  decimal_value = 0
  power = 0
  # Iterate through the digits in reverse order
  for digit in reversed(number_str):
    decimal_value += digit_to_decimal(digit.upper()) * (base ** power)
    power += 1
  return decimal_value

# %%
numero_original_str = str(input("Ingresa un numero: ")).upper()
base_original = int(input("En que base es el numero que ingresaste? (2, 3, 4, 5, 6, 7, 10 o 16): "))

numero_base_10 = 0
potencia = 0
# Iterate through the digits in reverse order
for i in reversed(numero_original_str):
  digito = 0
  if '0' <= i <= '9':
    digito = int(i)
  elif 'A' <= i <= 'F':
    digito = ord(i) - ord('A') + 10
  else:
    print(f"Error: Invalid digit '{i}' for base {base_original}")
    # You might want to exit or handle this error differently
    exit()
  numero_base_10 = numero_base_10 + (digito * (base_original ** potencia))
  potencia = potencia + 1

print(f"The decimal value of {numero_original_str} in base {base_original} is: {numero_base_10}")
# Out:
# Ingresa un numero: 16d
# En que base es el numero que ingresaste? (2, 3, 4, 5, 6, 7, 10 o 16): 16
# The decimal value of 16D in base 16 is: 365

# %%
numero_original_str = str(input("Ingresa un numero: ")).upper()
base_original = int(input("En que base es el numero que ingresaste? (2, 3, 4, 5, 6, 7, 10 o 16): "))

numero_base_10 = 0
potencia = 0
# Iterate through the digits in reverse order
for i in reversed(numero_original_str):
  digito = 0
  if '0' <= i <= '9':
    digito = int(i)
  else:
    digito = ord(i) - ord('A') + 10

  numero_base_10 = numero_base_10 + (digito * (base_original ** potencia))
  potencia = potencia + 1

print(f"The decimal value of {numero_original_str} in base {base_original} is: {numero_base_10}")
# Out:
# Ingresa un numero: 16d
# En que base es el numero que ingresaste? (2, 3, 4, 5, 6, 7, 10 o 16): 16
# The decimal value of 16D in base 16 is: 365
