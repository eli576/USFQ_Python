# %% [markdown]
# <a href="https://colab.research.google.com/github/eli576/USFQ_Python/blob/main/USFQ_Python_clase_15_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total = 0
for i in range(1,101):
  if i%2 != 0:
    total += i
    #total = total + i
print("La suma de los numeros impares es: ", total)
# Out:
# La suma de los numeros impares es:  2500

# %%
import math

n = int(input("Ingresa un numero n: "))
m = int(input("Ingresa un numero m: "))

suma_k = 0
for k in range (0, n+1):
  suma_i = 0
  for i in range (0, m+1):
    suma_i += (((-k)**i)/(math.factorial(i)))
    #elevado son ** no ^
  suma_k += suma_i

print(suma_k)
# Out:
# Ingresa un numero n: 10
# Ingresa un numero m: 50
# 1.5819502851672698

# %%
n = int(input("Ingresa un numero n: "))

factorial = 1
for i in range (1, n+1):
  factorial = factorial * i
print (factorial)
# Out:
# Ingresa un numero n: 5
# 120

# %%
n = int(input("Ingresa un numero n: "))

for i in range(1, n+1):
  if i%7 == 0:
    print("PUM")
  elif '7' in str(i):
    print("PUM")
  else:
    print(i)
# Out:
# Ingresa un numero n: 56
# 1
# 2
# 3
# 4
# 5
# 6
# PUM
# 8
# 9
# 10
# 11
# 12
# 13
# PUM
# 15
# 16
# PUM
# 18
# 19
# 20
# PUM
# 22
# 23
# 24
# 25
# 26
# PUM
# PUM
# 29
# 30
# 31
# 32
# 33
# 34
# PUM
# 36
# PUM
# 38
# 39
# 40
# 41
# PUM
# 43
# 44
# 45
# 46
# PUM
# 48
# PUM
# 50
# 51
# 52
# 53
# 54
# 55
# PUM

# %%
x = int(input("Ingresa la cantidad de dinero que tienes en tu cuenta de ahorros ahora: "))
interes = x*0.05
balance = x
for i in range (1,31):
  balance = balance + interes
  #print(balance)
y = int(input("Ingresa la cantidad de dinero que añadaste: "))
balance = balance + y
for i in range (1,61):
  balance = balance + interes
  #print(balance)
print (f"Tu balance despues the 90 dias es: {balance:.2f}")
# Out:
# Ingresa la cantidad de dinero que tienes en tu cuenta de ahorros ahora: 10
# Ingresa la cantidad de dinero que anadaste: 5
# Tu balance despues the 90 dias es: 60.00
