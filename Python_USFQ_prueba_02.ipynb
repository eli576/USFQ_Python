# %% [markdown]
# <a href="https://colab.research.google.com/github/eli576/USFQ_Python/blob/main/Python_USFQ_prueba_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Ingresa un numero entero: "))

suma = 0

for i in range(1, n+1):
  producto = 1
  for j in range (1, i+1):
    producto = producto * j
  suma = suma + producto

print(suma)
# Out:
# Ingresa un numero entero: 5
# 153

# %%
#validacion
answer = 120+24+6+2+1
print(answer)
# Out:
# 153
